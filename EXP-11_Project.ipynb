# %% [markdown]
# # 11-6. 프로젝트 : 폐렴 진단기 성능개선
# 조금 전까지 우리는 대략 80% 정도의 정확도를 가진 X-RAY 사진 판독 폐렴 진단기를 만들어 보았습니다.
#
# 하지만 숙련된 의사분들은 90% 이상에 도달한다고 하니, 좀 더 분발해야겠죠?
#
# 그렇다면 우리는 조금 전까지의 실습 과정을 되짚어보면서, 어떤 점을 더 개선해볼 수 있을지 따져 보고 스스로 개선해 가면서 더 성능을 향상시켜 보려고 합니다.

# %% [markdown]
# ## Step 0. 환경 구축

# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*'
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 16
EPOCHS = 25

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

# 이제 파일 경로에 NORMAL이 있는지 확인하면 정상 이미지를 셀 수 있습니다.
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")

# 파일 경로에 PNEUMONIA이 있는지 확인하면 폐렴 이미지도 셀 수 있습니다.
COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1090
# Pneumonia images count in training set: 3095

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(5,math.ceil(BATCH_SIZE/5),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.92
# Weight for PNEUMONIA: 0.68

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 66s 139ms/step - loss: 0.5524 - accuracy: 0.7041 - precision: 0.9045 - recall: 0.6665 - val_loss: 0.5658 - val_accuracy: 0.7529 - val_precision: 0.7529 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.2428 - accuracy: 0.9073 - precision: 0.9749 - recall: 0.8970 - val_loss: 1.0826 - val_accuracy: 0.7548 - val_precision: 0.7548 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 34s 129ms/step - loss: 0.1914 - accuracy: 0.9235 - precision: 0.9768 - recall: 0.9181 - val_loss: 0.3667 - val_accuracy: 0.8481 - val_precision: 0.8321 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 34s 129ms/step - loss: 0.1564 - accuracy: 0.9444 - precision: 0.9832 - recall: 0.9407 - val_loss: 0.6376 - val_accuracy: 0.7625 - val_precision: 0.7600 - val_recall: 1.0000
# Epoch 5/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1720 - accuracy: 0.9355 - precision: 0.9776 - recall: 0.9335 - val_loss: 0.1299 - val_accuracy: 0.9500 - val_precision: 0.9867 - val_recall: 0.9464
# Epoch 6/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1567 - accuracy: 0.9441 - precision: 0.9802 - recall: 0.9444 - val_loss: 0.2875 - val_accuracy: 0.8942 - val_precision: 1.0000 - val_recall: 0.8595
# Epoch 7/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1430 - accuracy: 0.9444 - precision: 0.9821 - recall: 0.9414 - val_loss: 0.0944 - val_accuracy: 0.9673 - val_precision: 0.9675 - val_recall: 0.9898
# Epoch 8/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1363 - accuracy: 0.9519 - precision: 0.9824 - recall: 0.9516 - val_loss: 0.0763 - val_accuracy: 0.9692 - val_precision: 0.9820 - val_recall: 0.9770
# Epoch 9/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1242 - accuracy: 0.9519 - precision: 0.9855 - recall: 0.9487 - val_loss: 0.0778 - val_accuracy: 0.9721 - val_precision: 0.9796 - val_recall: 0.9834
# Epoch 10/25
# 261/261 [==============================] - 34s 129ms/step - loss: 0.1086 - accuracy: 0.9553 - precision: 0.9919 - recall: 0.9470 - val_loss: 0.0677 - val_accuracy: 0.9721 - val_precision: 0.9821 - val_recall: 0.9809
# Epoch 11/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1094 - accuracy: 0.9590 - precision: 0.9873 - recall: 0.9569 - val_loss: 0.1958 - val_accuracy: 0.9173 - val_precision: 1.0000 - val_recall: 0.8899
# Epoch 12/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1324 - accuracy: 0.9509 - precision: 0.9909 - recall: 0.9428 - val_loss: 0.0818 - val_accuracy: 0.9702 - val_precision: 0.9883 - val_recall: 0.9719
# Epoch 13/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.1107 - accuracy: 0.9617 - precision: 0.9921 - recall: 0.9554 - val_loss: 0.1293 - val_accuracy: 0.9394 - val_precision: 0.9932 - val_recall: 0.9259
# Epoch 14/25
# 261/261 [==============================] - 34s 129ms/step - loss: 0.1147 - accuracy: 0.9555 - precision: 0.9914 - recall: 0.9475 - val_loss: 0.0987 - val_accuracy: 0.9606 - val_precision: 0.9856 - val_recall: 0.9616
# Epoch 15/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.1077 - accuracy: 0.9557 - precision: 0.9858 - recall: 0.9533 - val_loss: 0.1279 - val_accuracy: 0.9606 - val_precision: 0.9535 - val_recall: 0.9962
# Epoch 16/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.0971 - accuracy: 0.9632 - precision: 0.9888 - recall: 0.9610 - val_loss: 0.1853 - val_accuracy: 0.9260 - val_precision: 0.9972 - val_recall: 0.9043
# Epoch 17/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.0781 - accuracy: 0.9704 - precision: 0.9936 - recall: 0.9664 - val_loss: 0.1151 - val_accuracy: 0.9587 - val_precision: 0.9920 - val_recall: 0.9527
# Epoch 18/25
# 261/261 [==============================] - 34s 129ms/step - loss: 0.0960 - accuracy: 0.9657 - precision: 0.9906 - recall: 0.9624 - val_loss: 0.2165 - val_accuracy: 0.9298 - val_precision: 0.9903 - val_recall: 0.9158
# Epoch 19/25
# 261/261 [==============================] - 34s 129ms/step - loss: 0.0684 - accuracy: 0.9763 - precision: 0.9973 - recall: 0.9706 - val_loss: 0.0823 - val_accuracy: 0.9654 - val_precision: 0.9947 - val_recall: 0.9591
# Epoch 20/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.0651 - accuracy: 0.9767 - precision: 0.9962 - recall: 0.9724 - val_loss: 0.0700 - val_accuracy: 0.9769 - val_precision: 0.9859 - val_recall: 0.9834
# Epoch 21/25
# 261/261 [==============================] - 34s 129ms/step - loss: 0.0958 - accuracy: 0.9697 - precision: 0.9917 - recall: 0.9673 - val_loss: 0.0615 - val_accuracy: 0.9712 - val_precision: 0.9909 - val_recall: 0.9706
# Epoch 22/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.0493 - accuracy: 0.9838 - precision: 0.9970 - recall: 0.9813 - val_loss: 0.3508 - val_accuracy: 0.8981 - val_precision: 0.8814 - val_recall: 0.9987
# Epoch 23/25
# 261/261 [==============================] - 34s 130ms/step - loss: 0.0735 - accuracy: 0.9713 - precision: 0.9930 - recall: 0.9680 - val_loss: 0.0767 - val_accuracy: 0.9712 - val_precision: 0.9833 - val_recall: 0.9783
# Epoch 24/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.0662 - accuracy: 0.9791 - precision: 0.9963 - recall: 0.9757 - val_loss: 0.0652 - val_accuracy: 0.9721 - val_precision: 0.9883 - val_recall: 0.9744
# Epoch 25/25
# 261/261 [==============================] - 34s 131ms/step - loss: 0.0793 - accuracy: 0.9675 - precision: 0.9914 - recall: 0.9639 - val_loss: 0.0879 - val_accuracy: 0.9760 - val_precision: 0.9761 - val_recall: 0.9923

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ## Step 1. 실험환경 Set-up
# 거의 바꿔볼 수 있을 게 없을 것 같지만, Batch size, Epoch 등을 변경해볼 수 있을 것입니다.

# %%
# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
# BATCH_SIZE : 16-> 32
# EPOCHS : 15- > 30

BATCH_SIZE = 16
EPOCHS = 25

# %% [markdown]
# ## Step 2. 데이터 준비하기
# 원본 데이터를 가져와서 전처리 및 배치 구성을 진행합니다. 의료 영상 이미지의 특성상 데이터는 언제나 충분하지 않습니다. 이를 극복할 수 있는 방법을 고민해 봅시다.
#
# 이전 실습에서 고려하지 않았던 augmentation 기법을 고려해 볼 수 있을 것입니다. 그러나 의료 영상인 경우, 일반적인 이미지 처리에서 사용하는 augmentation들이 항상 도움이 된다고 말할 수 없습니다. 특히 X-RAY 같은 의료 영상의 특성상, 육안으로도 구분하기 어려운 미묘한 차이에 더해진 노이즈 등 부수효과가 오히려 방해를 줄 수도 있기 때문입니다. 그래서 augmentation 도입은 신중해야 합니다.
#
# 만약 예를 들어 좌우 반전 정도의 augmentation만 도입한다고 한다면 다음과 같이 진행될 것입니다.

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
    return image,label

def prepare_for_training(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수에 추가되었습니다.
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds


train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# ## Step 3. 데이터 시각화
# 학습용 데이터를 시각화해서 확인해 봅니다. 만약 augmentation을 시도했다면 이후 실습 코드에 있는 show_batch() 함수를 통해 실제로 좌우 반전 등이 제대로 처리되었는지 확인해 봅시다.

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(5,math.ceil(BATCH_SIZE/5),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# ## Step 4. CNN 모델링
# 의료 영상 판독을 위해 실습에서 구현했던 model에서 다양한 것들을 바꾸어 가며 실험해볼 수 있습니다. Convolution filter, 채널 개수, activation, 모델 구조 등을 다양하게 바꾸어볼 수 있습니다.
#
# 그리고, 우리는 BatchNormalization과 Dropout을 한 모델 안에서 동시에 사용하는 특이한 구성을 실습했습니다. 이것은 일반적으로 잘 사용되는 형태는 아닙니다. 하지만 이미지 사이즈가 크고 데이터가 부족한 의료 영상에서는 실용적으로 간혹 좋은 성능을 보이기도 합니다. 만약 이 구성을 변경해 보면 어떤 효과가 발생하는지도 실험해 봅시다. BatchNormalization을 쓰거나 혹은 쓰지 않거나, Dropout을 쓰거나 혹은 쓰지 않거나 할 수 있습니다. 또, Dropout 비율을 변경해볼 수도 있습니다.

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ## Step 5. 데이터 imbalance 처리
# 실습 코드에서 데이터의 imbalance 문제에 대처하기 위해 데이터 비율로 나누어진 class_weight를 설정해 주었습니다. 만약 이러한 처리를 생략한다면 어떻게 될까요? 또 recall을 강조하기 위해 폐렴 데이터를 잘 맞추는 것을 더 강화하는 효과를 만들어낼 수는 없을까요?

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.92
# Weight for PNEUMONIA: 0.68

# %% [markdown]
# ## Step 6. 모델 훈련
# loss 함수를 변경하기는 어렵겠지만, optimizer나 learning rate 등의 변화를 고려해볼 수 있을 것입니다.

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 48s 145ms/step - loss: 0.5350 - accuracy: 0.7239 - precision: 0.9175 - recall: 0.6844 - val_loss: 0.6026 - val_accuracy: 0.7510 - val_precision: 0.7510 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 37s 141ms/step - loss: 0.2440 - accuracy: 0.9040 - precision: 0.9741 - recall: 0.8936 - val_loss: 0.8611 - val_accuracy: 0.7548 - val_precision: 0.7548 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 37s 143ms/step - loss: 0.2011 - accuracy: 0.9240 - precision: 0.9758 - recall: 0.9195 - val_loss: 0.9778 - val_accuracy: 0.7529 - val_precision: 0.7526 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 38s 145ms/step - loss: 0.1789 - accuracy: 0.9335 - precision: 0.9807 - recall: 0.9276 - val_loss: 0.5651 - val_accuracy: 0.7548 - val_precision: 1.0000 - val_recall: 0.6739
# Epoch 5/25
# 261/261 [==============================] - 39s 148ms/step - loss: 0.1712 - accuracy: 0.9357 - precision: 0.9815 - recall: 0.9296 - val_loss: 0.1004 - val_accuracy: 0.9625 - val_precision: 0.9674 - val_recall: 0.9834
# Epoch 6/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.1490 - accuracy: 0.9400 - precision: 0.9855 - recall: 0.9322 - val_loss: 0.1024 - val_accuracy: 0.9654 - val_precision: 0.9662 - val_recall: 0.9885
# Epoch 7/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.1481 - accuracy: 0.9457 - precision: 0.9837 - recall: 0.9410 - val_loss: 0.0964 - val_accuracy: 0.9644 - val_precision: 0.9583 - val_recall: 0.9962
# Epoch 8/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.1567 - accuracy: 0.9375 - precision: 0.9789 - recall: 0.9363 - val_loss: 0.1898 - val_accuracy: 0.9067 - val_precision: 0.9928 - val_recall: 0.8828
# Epoch 9/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.1462 - accuracy: 0.9391 - precision: 0.9870 - recall: 0.9296 - val_loss: 0.0889 - val_accuracy: 0.9702 - val_precision: 0.9808 - val_recall: 0.9796
# Epoch 10/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.1357 - accuracy: 0.9508 - precision: 0.9820 - recall: 0.9504 - val_loss: 0.1772 - val_accuracy: 0.9250 - val_precision: 0.9930 - val_recall: 0.9066
# Epoch 11/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.1367 - accuracy: 0.9453 - precision: 0.9877 - recall: 0.9389 - val_loss: 0.1634 - val_accuracy: 0.9298 - val_precision: 0.9944 - val_recall: 0.9119
# Epoch 12/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.1304 - accuracy: 0.9474 - precision: 0.9858 - recall: 0.9429 - val_loss: 0.1138 - val_accuracy: 0.9625 - val_precision: 0.9535 - val_recall: 0.9987
# Epoch 13/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.1274 - accuracy: 0.9518 - precision: 0.9856 - recall: 0.9489 - val_loss: 0.1122 - val_accuracy: 0.9490 - val_precision: 0.9803 - val_recall: 0.9515
# Epoch 14/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.1065 - accuracy: 0.9566 - precision: 0.9905 - recall: 0.9510 - val_loss: 0.2032 - val_accuracy: 0.9269 - val_precision: 0.9745 - val_recall: 0.9272
# Epoch 15/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.1299 - accuracy: 0.9518 - precision: 0.9871 - recall: 0.9466 - val_loss: 0.0858 - val_accuracy: 0.9692 - val_precision: 0.9896 - val_recall: 0.9693
# Epoch 16/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.1106 - accuracy: 0.9556 - precision: 0.9858 - recall: 0.9534 - val_loss: 0.1150 - val_accuracy: 0.9548 - val_precision: 0.9718 - val_recall: 0.9680
# Epoch 17/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.1064 - accuracy: 0.9550 - precision: 0.9873 - recall: 0.9513 - val_loss: 0.0797 - val_accuracy: 0.9635 - val_precision: 0.9882 - val_recall: 0.9630
# Epoch 18/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.1111 - accuracy: 0.9523 - precision: 0.9899 - recall: 0.9453 - val_loss: 0.0936 - val_accuracy: 0.9567 - val_precision: 0.9920 - val_recall: 0.9501
# Epoch 19/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.1047 - accuracy: 0.9547 - precision: 0.9877 - recall: 0.9503 - val_loss: 0.0598 - val_accuracy: 0.9740 - val_precision: 0.9846 - val_recall: 0.9808
# Epoch 20/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.0872 - accuracy: 0.9674 - precision: 0.9903 - recall: 0.9646 - val_loss: 0.0621 - val_accuracy: 0.9798 - val_precision: 0.9835 - val_recall: 0.9898
# Epoch 21/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.0835 - accuracy: 0.9668 - precision: 0.9919 - recall: 0.9625 - val_loss: 0.0799 - val_accuracy: 0.9712 - val_precision: 0.9796 - val_recall: 0.9821
# Epoch 22/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.0672 - accuracy: 0.9738 - precision: 0.9954 - recall: 0.9694 - val_loss: 0.0807 - val_accuracy: 0.9663 - val_precision: 0.9895 - val_recall: 0.9655
# Epoch 23/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.1133 - accuracy: 0.9592 - precision: 0.9901 - recall: 0.9543 - val_loss: 0.0615 - val_accuracy: 0.9750 - val_precision: 0.9909 - val_recall: 0.9757
# Epoch 24/25
# 261/261 [==============================] - 38s 147ms/step - loss: 0.0800 - accuracy: 0.9698 - precision: 0.9908 - recall: 0.9678 - val_loss: 0.1163 - val_accuracy: 0.9644 - val_precision: 0.9582 - val_recall: 0.9962
# Epoch 25/25
# 261/261 [==============================] - 38s 146ms/step - loss: 0.0908 - accuracy: 0.9661 - precision: 0.9922 - recall: 0.9620 - val_loss: 0.0782 - val_accuracy: 0.9683 - val_precision: 0.9870 - val_recall: 0.9706

# %% [markdown]
# #### * accuracy : 0.96

# %% [markdown]
# ## Step 7. 결과 확인과 시각화
# 테스트 데이터로 훈련된 모델을 평가해 봅시다. 우선은 accuracy를 고려해야겠지만 의료 영상 모델의 특성상 recall도 중요합니다. 훈련과정의 history 그래프를 시각화해 보고, 학습 진행 양상을 면밀히 분석해 보는 것도 잊지 않도록 합시다.

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ## 회고

# %% [markdown]
# ### 1. 이번 프로젝트에서 어려웠던 점
#
# >이미지에 데이터에 대한 전처리 및 변환방식

# %% [markdown]
# ### 2. 프로젝트를 진행하면서 알아낸 점 혹은 아직 모호한 점
# >알아낸 점 : 데이터 imbalance 처리
# >
# >모호한 점 : parameter 조절시 어떤 기준에 의해서 하는지..

# %% [markdown]
# ### 3. 루브릭 평가 지표를 맞추기 위해 시도한 것들.
# >epoch와 batch_size를 각각 조절하였음, conv

# %% [markdown]
# ### 4. 만약에 루브릭 평가 관련 지표를 달성 하지 못했을 때, 이유에 관한 추정.
#
# > 많은 시간을 투자하지 못 함, 다른 숙제 및 발표준비로 인해서..

# %% [markdown]
# ### 5. 자기 다짐
#
# >다음번 exp는 더 잘해보도록 노력하자!!
